# %% [markdown]
# # Modeling

# %% [markdown]
# ### Import Libraries

# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading dataset

# %%
buys_df = pd.read_csv('/work/data/buys_df_enriched.csv')

# %% [markdown]
# ### Supervised Model

# %%
data = buys_df.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1540 entries, 0 to 1539
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NUM BEN                 1540 non-null   int64
#  1   BENEFICIARIO            1540 non-null   object
#  2   RFC                     1540 non-null   object
#  3   FACTURA                 1540 non-null   object
#  4   CONTRATO                1540 non-null   object
#  5   CONCEPTO                1540 non-null   object
#  6   TIPO                    1540 non-null   object
#  7   # OP                    1540 non-null   float64
#  8   FECHA                   1540 non-null   object
#  9   SHEET                   1540 non-null   object
#  10  DIA                     1540 non-null   int64
#  11  MES                     1540 non-null   int64
#  12  ANO                     1540 non-null   int64
#  13  BENEFICIARIO_SALES      1540 non-null   int64
# ...

# %%
data.isnull().sum()
# Out:
# NUM BEN                   0
# BENEFICIARIO              0
# RFC                       0
# FACTURA                   0
# CONTRATO                  0
# CONCEPTO                  0
# TIPO                      0
# # OP                      0
# FECHA                     0
# SHEET                     0
# DIA                       0
# MES                       0
# ANO                       0
# BENEFICIARIO_SALES        0
# IMPORTE_GASTO_PROMEDIO    0
# HAS_LINKEDIN_SITE         0
# dtype: int64

# %%
data = buys_df.copy()
for i, column in enumerate(list([str(d) for d in data.dtypes])):
    if column == "object":
        data[data.columns[i]] == data[data.columns[i]].fillna(data[data.columns[i]].mode())
        data[data.columns[i]] == data[data.columns[i]].astype("category").cat.codes
    else:
        data[data.columns[i]] == data[data.columns[i]].fillna(data[data.columns[i]].median())

# %%
data.head(5)
# Out:
#    NUM BEN                                    BENEFICIARIO           RFC  \
# 0   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 1   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 2   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 3   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
# 4   110152  LLANTAS Y SERVICIOS SERNA ANAHUAC,S.A. DE C.V.  LSS841015DV3
#
#                   FACTURA      CONTRATO  \
# 0  LLS AF8458-158008-3972  OT. 20204373
# 1  LLS PF6916-158008-4041  OT. 20204425
# 2  LLS PF6917-158008-3975  OT. 20204376
# 3  LLS PF7004-158008-3971  OT. 20204374
# 4  LLS PF7137-158008-4554  OT. 20205130
#
#                                             CONCEPTO TIPO         # OP  \
# 0  REEMPLAZO E INSTALACION DE AMORTIGUADORES (DEL...   TR    1019110.0
# 1  REEMPLAZO E INSTALACION DE OCHO BIRLOS Y NUEVE...   TR    1019110.0
# ...

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
y = data.pop('IMPORTE')
X = data.copy()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
clf = RandomForestRegressor(n_estimators = 1000, max_depth = 4)

# %%
# clf.fit(X_train, y_train)

# %%
from sklearn.metrics import r2_score

# %%
# r2_score(y_test, clf.predict(X_test))

# %% [markdown]
# ### Text Clustering Unsupervised Model

# %%
import gensim
from nltk.corpus import stopwords

# %%
def preprocess(text):
    result = []
    for token in text.split():
        if token not in stopwords.words('spanish') and len(token) > 4:
            result.append(toke)
    return result

# %%
# process_business = [preprocess(x) for x in list(buys_df['BENEFICIARIO'].unique())]

# %%
# dictionary = gensim.corpora.Dictionary(process_business)

# %%
# dictionary.filter_extremes(no_below=1, no_above=0.5)

# %%
# bow_corpus = [dictionary.doc2bow(doc) for doc in process_business]

# %%
# lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=6, id2word=dictionary, passes=10, workers=2)

# %%
# for idx, type_business in lda_model.print_topics(-1):
#     print('Topics:{} Words:{}'. format(idx, type_business))

# %%
def get_max_topic(index):
    results = lda_model[bow_corpus[index]]
    return max(lda_model[results], key = lambda x: x[1]) [0]

# %%
# business_cluster = {x: get_max_topic(i) for i, x in enumerate(list(buys_df['BENEFICIARIO'].unique()))}

# %%
buys_df['CLUSTER NAME'] = buys_df['BENEFICIARIO'].apply(lambda x: business_cluster[x])

# %%
# buys_df.groupby('CLUSTER_NAME')['IMPORTE'].mean().plot.bar()

# %% [markdown]
# ### Anomalies Unsupervised Model

# %%
from scipy.stats import norm

# %%
# params = norm.fit(buys_df['IMPORTE'])

# %%
# params/

# %%
# buys_df['PROB_TOTAL'] = [norm(params[0], params[1]).cdf(x)for x in buys_df['IMPORTE']]

# %%
# buys_df['PROB_TOTAL'].hist()
# plt.show()

# %%
# buys_df['PROB_TOTAL'] > 0.95

# %%
# models_sheet = {}
# for sheet in list(buys_df['SHEET'].unique()):
#     sheet_buys = buys_df[buys_df['SHEET'] == sheet]
#     params = norm.fit(sheet_buys['IMPORTE'])
#     models_sheet[sheet] = norm(params[0], params[1])

# %%
# sheet_prob = []
# for i, row in buys_df.iterrows():
#     sheet_prob.append(models_sheet[row['SHEET']].cdf(row['IMPORTE']))
# buys_df['PROB_SHEET'] = sheet_prob

# %%
# buys_df['PROB_SHEET'].hist()

# %% [markdown]
# ### Conclusions

# %% [markdown]
# - central tendency approach

# %% [markdown]
# - Outlier's stories

# %% [markdown]
# - focus on answer the main question

# %% [markdown]
# - If the scope change, document it

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=a87f5222-8f82-4f1e-bb77-44a63aa36742' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
